# %%
from main import RandomDatasetGenerator

config = [
    {"name": "age", "type": "integer", "params": {"low": 18, "high": 65}},
    {"name": "income", "type": "float", "distribution": "normal", "params": {"loc": 50000, "scale": 15000}},
    {"name": "name", "type": "name"},
    {"name": "email", "type": "email"},
    {"name": "job", "type": "job"}
]
generator = RandomDatasetGenerator(seed=42)
generator.generate_dataset(n_rows=100, columns_config=config)
# Out:
#     age        income              name                        email  \
# 0    51  56912.244502      Allison Hill  davenportbrandi@example.org
# 1    92  51288.852074       Noah Rhodes        tanderson@example.com
# 2    14  27350.640767   Angie Henderson       nolanjason@example.org
# 3    71  60822.536935     Daniel Wagner       gomezanita@example.com
# 4    60  37348.701150   Cristian Santos        sarayoung@example.org
# ..  ...           ...               ...                          ...
# 95   39  51214.562089    Anna Henderson    mcknightdavid@example.com
# 96   84  43753.154547        Aaron Wise    kimberlyjames@example.com
# 97   79  62862.548774  Deborah Figueroa       michelle64@example.net
# 98   81  60771.924197     Jessica Smith        lynchjody@example.org
# 99   52  35727.923740     Stephen Mckee     josephmiller@example.org
#
#                                       job
# 0                     Early years teacher
# 1                                     Sub
# 2                              Cabin crew
# 3                       Designer, graphic
# 4                   Accountant, chartered
# ..                                    ...
# 95                        Patent attorney
# 96                 Audiological scientist
# 97  Emergency planning/management officer
# 98                      Scientist, marine
# 99                    Medical illustrator
#
# [100 rows x 5 columns]
